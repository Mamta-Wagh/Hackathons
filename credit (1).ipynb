# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df1=pd.read_csv("D://mamta//train_curfew.csv")
df2=pd.read_csv("D://mamta//test_curfew.csv")
df=pd.concat([df1,df2],keys=("train","test"))

# %%
df1.shape
# Out:
# (21000, 25)

# %%
df2.shape
# Out:
# (9000, 24)

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.head()
# Out:
#             ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# train 0  25150     360000    2          2         2   25     -1     -1     -1
#       1  13470     240000    2          1         2   46      2      2     -2
#       2   3092     320000    2          2         1   41      0      0      0
#       3  13973      50000    2          2         2   24     -1     -1     -2
#       4  10567      80000    1          3         1   52     -1      0      0
#
#          PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# train 0     -1  ...       3435       8870       2020     12590      3479
#       1     -1  ...       2240       1681       2267         0         0
#       2      0  ...      35409      35036      35939      5000      2000
#       3     -2  ...          0          0          0         0         0
#       4      0  ...      20561      21261      21457      1500      1500
#
# ...

# %%
df.isnull().sum()
# Out:
# ID                               0
# LIMIT_BAL                        0
# SEX                              0
# EDUCATION                        0
# MARRIAGE                         0
# AGE                              0
# PAY_0                            0
# PAY_2                            0
# PAY_3                            0
# PAY_4                            0
# PAY_5                            0
# PAY_6                            0
# BILL_AMT1                        0
# BILL_AMT2                        0
# BILL_AMT3                        0
# BILL_AMT4                        0
# BILL_AMT5                        0
# BILL_AMT6                        0
# PAY_AMT1                         0
# PAY_AMT2                         0
# PAY_AMT3                         0
# PAY_AMT4                         0
# PAY_AMT5                         0
# PAY_AMT6                         0
# default_payment_next_month    9000
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30000 entries, ('train', 0) to ('test', 8999)
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
df.corr()
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.026179  0.018497   0.039177
# LIMIT_BAL                   0.026179   1.000000  0.024755  -0.219161
# SEX                         0.018497   0.024755  1.000000   0.014232
# EDUCATION                   0.039177  -0.219161  0.014232   1.000000
# MARRIAGE                   -0.029079  -0.108139 -0.031389  -0.143464
# AGE                         0.018678   0.144713 -0.090874   0.175061
# PAY_0                      -0.030575  -0.271214 -0.057643   0.105364
# PAY_2                      -0.011215  -0.296382 -0.070771   0.121566
# PAY_3                      -0.018494  -0.286123 -0.066096   0.114025
# PAY_4                      -0.002735  -0.267460 -0.060173   0.108793
# PAY_5                      -0.022199  -0.249411 -0.055064   0.097520
# PAY_6                      -0.020270  -0.235195 -0.044008   0.082316
# BILL_AMT1                   0.019389   0.285430 -0.033642   0.023581
# ...

# %%
df.PAY_AMT4.unique()
# Out:
# array([ 8870,     0,  3000, ..., 12820, 25420, 16405], dtype=int64)

# %%
x=df.drop(["default_payment_next_month","ID","SEX","EDUCATION","MARRIAGE","AGE"],axis=1)
y=df["default_payment_next_month"]
x_train=x.iloc[0:21000,:]
y_train=y.iloc[0:21000]
x_test=x.iloc[21000:,:]
y_test=y.iloc[21000:]

# %%
y_train.tail()
# Out:
# train  20995    0.0
#        20996    0.0
#        20997    1.0
#        20998    0.0
#        20999    1.0
# Name: default_payment_next_month, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_train_pred=lr.predict(x_train)

# %%
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,roc_auc_score
acc=accuracy_score(y_train,y_train_pred)
acc
# Out:
# 0.7788095238095238

# %%
y_pred=lr.predict(x_test)

# %%
w1=pd.DataFrame(y_pred)
w2=pd.DataFrame(df2["ID"])
w=pd.concat([w1,w2],axis=1)
w.to_csv('E:/credit.csv')

# %%
from sklearn import tree
dt=tree.DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_train_pred1=dt.predict(x_train)
acc1=accuracy_score(y_train_pred1,y_train)
acc1
# Out:
# 0.9910476190476191

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=10)
rf.fit(x_train,y_train)
y_train_pred2=rf.predict(x_train)
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,roc_auc_score
a1=accuracy_score(y_train,y_train_pred2)
a1
# Out:
# 0.9724761904761905

# %%
from sklearn.svm import SVC
classifier=SVC(kernel="rbf")
classifier.fit(x_train,y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
from sklearn.svm import SVC
classifier=SVC(kernel="rbf")
classifier.fit(x_train,y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
# !pip install lightgbm
import lightgbm as lgb
model = lgb.LGBMClassifier()
model.fit(x_train,y_train)
# Out:
# ...
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
from sklearn.metrics import accuracy_score
predict_train = model.predict(x_train)
accuracy_train = accuracy_score(y_train,predict_train)

# %%
print(accuracy_train)
# Out:
# 0.8445714285714285

# %%
predict_test = model.predict(x_test)

# %%
w1=pd.DataFrame(predict_test)
w2=pd.DataFrame(df2["ID"])
w=pd.concat([w2,w1],axis=1)
w.to_csv('E:/credit1.csv')
